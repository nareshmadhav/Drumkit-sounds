# %% [markdown]
# <a href="https://colab.research.google.com/github/nareshmadhav/Drumkit-sounds/blob/main/Stduent_preformance.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd
from matplotlib import pyplot as plt
import seaborn as sns

# %%
data=pd.read_csv('/content/StudentsPerformance.csv')
df=pd.DataFrame(data)
df
# Out:
#      gender race/ethnicity parental level of education         lunch  \
# 0    female        group B           bachelor's degree      standard
# 1    female        group C                some college      standard
# 2    female        group B             master's degree      standard
# 3      male        group A          associate's degree  free/reduced
# 4      male        group C                some college      standard
# ..      ...            ...                         ...           ...
# 995  female        group E             master's degree      standard
# 996    male        group C                 high school  free/reduced
# 997  female        group C                 high school  free/reduced
# 998  female        group D                some college      standard
# 999  female        group D                some college  free/reduced
#
#     test preparation course  math score  reading score  writing score
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1000 entries, 0 to 999
# Data columns (total 8 columns):
#  #   Column                       Non-Null Count  Dtype
# ---  ------                       --------------  -----
#  0   gender                       1000 non-null   object
#  1   race/ethnicity               1000 non-null   object
#  2   parental level of education  1000 non-null   object
#  3   lunch                        1000 non-null   object
#  4   test preparation course      1000 non-null   object
#  5   math score                   1000 non-null   int64
#  6   reading score                1000 non-null   int64
#  7   writing score                1000 non-null   int64
# dtypes: int64(3), object(5)
# memory usage: 62.6+ KB

# %%
df.describe()
# Out:
#        math score  reading score  writing score
# count  1000.00000    1000.000000    1000.000000
# mean     66.08900      69.169000      68.054000
# std      15.16308      14.600192      15.195657
# min       0.00000      17.000000      10.000000
# 25%      57.00000      59.000000      57.750000
# 50%      66.00000      70.000000      69.000000
# 75%      77.00000      79.000000      79.000000
# max     100.00000     100.000000     100.000000

# %%
df.dtypes
# Out:
# gender                         object
# race/ethnicity                 object
# parental level of education    object
# lunch                          object
# test preparation course        object
# math score                      int64
# reading score                   int64
# writing score                   int64
# dtype: object

# %%
df.isnull().sum()
# Out:
# gender                         0
# race/ethnicity                 0
# parental level of education    0
# lunch                          0
# test preparation course        0
# math score                     0
# reading score                  0
# writing score                  0
# dtype: int64

# %%
df.duplicated(['gender','math score']).sum()
# Out:
# np.int64(853)

# %%
df.head(3)
# Out:
#    gender race/ethnicity parental level of education     lunch  \
# 0  female        group B           bachelor's degree  standard
# 1  female        group C                some college  standard
# 2  female        group B             master's degree  standard
#
#   test preparation course  math score  reading score  writing score
# 0                    none          72             72             74
# 1               completed          69             90             88
# 2                    none          90             95             93

# %%
df.shape
# Out:
# (1000, 8)

# %%
df.nunique()
# Out:
# gender                          2
# race/ethnicity                  5
# parental level of education     6
# lunch                           2
# test preparation course         2
# math score                     81
# reading score                  72
# writing score                  77
# dtype: int64

# %%
df.columns
# Out:
# Index(['gender', 'race/ethnicity', 'parental level of education', 'lunch',
#        'test preparation course', 'math score', 'reading score',
#        'writing score'],
#       dtype='object')

# %% [markdown]
# Unique is used to understand the columns in the data set

# %%
for x in df.columns:
  print(f"Categories in {x} : {df[x].unique()}")
# Out:
# Categories in gender : ['female' 'male']
# Categories in race/ethnicity : ['group B' 'group C' 'group A' 'group D' 'group E']
# Categories in parental level of education : ["bachelor's degree" 'some college' "master's degree" "associate's degree"
#  'high school' 'some high school']
# Categories in lunch : ['standard' 'free/reduced']
# Categories in test preparation course : ['none' 'completed']
# Categories in math score : [ 72  69  90  47  76  71  88  40  64  38  58  65  78  50  18  46  54  66
#   44  74  73  67  70  62  63  56  97  81  75  57  55  53  59  82  77  33
#   52   0  79  39  45  60  61  41  49  30  80  42  27  43  68  85  98  87
#   51  99  84  91  83  89  22 100  96  94  48  35  34  86  92  37  28  24
#   26  95  36  29  32  93  19  23   8]
# Categories in reading score : [ 72  90  95  57  78  83  43  64  60  54  52  81  53  75  89  32  42  58
#   69  73  71  74  70  65  87  56  61  84  55  44  41  85  59  17  39  80
# ...

# %% [markdown]
# Adding column to the data set

# %%
df['total score']=df['math score']+df['reading score']+df['writing score']
df['average']=df['total score']/3
df.head()
# Out:
#    gender race/ethnicity parental level of education         lunch  \
# 0  female        group B           bachelor's degree      standard
# 1  female        group C                some college      standard
# 2  female        group B             master's degree      standard
# 3    male        group A          associate's degree  free/reduced
# 4    male        group C                some college      standard
#
#   test preparation course  math score  reading score  writing score  \
# 0                    none          72             72             74
# 1               completed          69             90             88
# 2                    none          90             95             93
# 3                    none          47             57             44
# 4                    none          76             78             75
#
#    total score    average
# 0          218  72.666667
# 1          247  82.333333
# 2          278  92.666667
# 3          148  49.333333
# ...

# %% [markdown]
# The new column name is gender status idf the male candidate is there print eligible for outdoor games else elgible for indoor and outdoor games

# %%
df['gender status']=['eligible for outdoor games' if x=='male' else 'eligible for indoor and outdoor games' for x in df['gender']]
df.head()
# Out:
#    gender race/ethnicity parental level of education         lunch  \
# 0  female        group B           bachelor's degree      standard
# 1  female        group C                some college      standard
# 2  female        group B             master's degree      standard
# 3    male        group A          associate's degree  free/reduced
# 4    male        group C                some college      standard
#
#   test preparation course  math score  reading score  writing score  \
# 0                    none          72             72             74
# 1               completed          69             90             88
# 2                    none          90             95             93
# 3                    none          47             57             44
# 4                    none          76             78             75
#
#    total score    average                          gender status
# 0          218  72.666667  eligible for indoor and outdoor games
# ...

# %%
# df['grade']=["A grade" if x>80 and x<=100 elif x>=50 and x<80 "B grade" for x in df['math score']]
# df['grade']=['A grade' if x>80 and x<=100 else 'B grade' if x>=50 and x<80 else 'C grade' for x in df['math score']]
# df.head()

# %%
grade=[]
for x in df['math score']:
  if x>80 and x<=100:
    grade.append('A grade')
  elif x>=50 and x<80:
    grade.append('B grade')
  elif x>=35 and x<50:
    grade.append('C grade')
  else:
    grade.append('Fail')
df['math_grade']=grade
df.head()
# Out:
#    gender race/ethnicity parental level of education         lunch  \
# 0  female        group B           bachelor's degree      standard
# 1  female        group C                some college      standard
# 2  female        group B             master's degree      standard
# 3    male        group A          associate's degree  free/reduced
# 4    male        group C                some college      standard
#
#   test preparation course  math score  reading score  writing score  \
# 0                    none          72             72             74
# 1               completed          69             90             88
# 2                    none          90             95             93
# 3                    none          47             57             44
# 4                    none          76             78             75
#
#    total score    average                          gender status math_grade
# 0          218  72.666667  eligible for indoor and outdoor games    B grade
# ...

# %%
reading_full=df[df['reading score']==100]['average'].count()
writing_full=df[df['writing score']==100]['average'].count()
math_full=df[df['math score']==100]['average'].count()
print(f'Number of students with full marks in reading : {reading_full}')
print(f'Number of students with full marks in writing : {writing_full}')
print(f'Number of students with full marks in math : {math_full}')
# Out:
# Number of students with full marks in reading : 17
# Number of students with full marks in writing : 14
# Number of students with full marks in math : 7

# %%
total_students=len(df)
percentage_math=(math_full/total_students)*100
percentage_reading=(reading_full/total_students)*100
percentage_writing=(writing_full/total_students)*100
print(f'Percentage of students with full marks in math : {percentage_math}')
print(f'Percentage of students with full marks in reading : {percentage_reading}')
print(f'Percentage of students with full marks in writing : {percentage_writing}')
# Out:
# Percentage of students with full marks in math : 0.7000000000000001
# Percentage of students with full marks in reading : 1.7000000000000002
# Percentage of students with full marks in writing : 1.4000000000000001

# %% [markdown]
# Get the student list who are scoring 100

# %%
x=df[df['math score']==100]
len(x)/len(df)*100
# Out:
# 0.7000000000000001

# %%
# how many people math score less than 20
x=df[df['math score']<=20]
len(x)/len(df) *100
# Out:
# 0.4

# %% [markdown]
# Subplots are pakages from matplolib it will accept three parameters.

# %%
fig,axs = plt.subplots(1,2,figsize=(15,5))
plt.subplot(121)
sns.histplot(data=df,x='average',bins=30,kde=True,color='g')
plt.subplot(122)
sns.histplot(data=df,x='average',kde=True,hue='gender')
plt.show()
